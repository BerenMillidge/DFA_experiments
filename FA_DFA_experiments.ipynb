# %% [markdown]
# # Load data

# %%
# Experiments with performance and improvements to Feedback Alignment (Lillicrap 2016) and Direct Feedback Alignment (DFA) (Nokland 2016)
import numpy as np
import matplotlib.pyplot as plt
import torch 
import torchvision
import torchvision.transforms as transforms
from copy import deepcopy
import torch.nn as nn
import torch.nn.functional as F
import math

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
num_batches= 10
num_train_batches=20
batch_size = 64

transform = transforms.Compose([transforms.ToTensor()])#, transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5))])


trainset = torchvision.datasets.MNIST(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=1)

testset = torchvision.datasets.MNIST(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=1)


def imshow(img):
    img = img / 2 + 0.5     # unnormalize
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()


def onehot(x):
    z = torch.zeros([len(x),10])
    for i in range(len(x)):
      z[i,x[i]] = 1
    return z.float().to(DEVICE)

dataset = list(iter(trainloader))
for i,(img, label) in enumerate(dataset):
  dataset[i] = (img.reshape(len(img),784) /255 ,label)

images, labels = dataset[0]
print("IMAGES: ", images.shape)
print("LABELS: ", labels.shape)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw
# Processing...
# Done!
# /pytorch/torch/csrc/utils/tensor_numpy.cpp:141: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program.
# IMAGES:  torch.Size([64, 784])
# LABELS:  torch.Size([64])

# %% [markdown]
# # Functions

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
def set_tensor(xs):
  return xs.float().to(DEVICE)

def tanh(xs):
    return torch.tanh(xs)

def linear(x):
    return x

def tanh_deriv(xs):
    return 1.0 - torch.tanh(xs) ** 2.0

def linear_deriv(x):
    return set_tensor(torch.ones((1,)))

def relu(xs):
  return torch.clamp(xs,min=0)

def relu_deriv(xs):
  rel = relu(xs)
  rel[rel>0] = 1
  return rel 

def softmax(xs):
  return torch.nn.softmax(xs)

def sigmoid(xs):
  return F.sigmoid(xs)

def sigmoid_deriv(xs):
  return F.sigmoid(xs) * (torch.ones_like(xs) - F.sigmoid(xs))
   
def edge_zero_pad(img,d):
  N,C, h,w = img.shape 
  x = torch.zeros((N,C,h+(d*2),w+(d*2))).to(DEVICE)
  x[:,:,d:h+d,d:w+d] = img
  return x


def accuracy(out, L):
  B,l = out.shape
  total = 0
  for i in range(B):
    if torch.argmax(out[i,:]) == torch.argmax(L[i,:]):
      total +=1
  return total/ B

#DEVICE="cpu"

# %% [markdown]
# # FC Layer

# %%
class FCLayer(object):
  def __init__(self, input_size,output_size,batch_size, learning_rate,f,df,use_backwards_weights=True,update_backwards_weights=False, use_backwards_nonlinearities=True,device="cpu"):
    self.input_size = input_size
    self.output_size = output_size
    self.batch_size = batch_size
    self.learning_rate = learning_rate
    self.f = f 
    self.df = df
    self.device = device
    self.use_backwards_weights = use_backwards_weights
    self.update_backwards_weights = update_backwards_weights
    self.use_backwards_nonlinearities = use_backwards_nonlinearities
    self.weights = torch.empty([self.input_size,self.output_size]).normal_(mean=0.0,std=0.05).to(self.device)
    if self.use_backwards_weights:
      self.backward_weights = torch.empty([self.output_size,self.input_size]).normal_(mean=0.0,std=0.05).to(self.device)

  def forward(self,x):
    self.inp = x.clone()
    self.activations = torch.matmul(self.inp, self.weights)
    return self.f(self.activations)

  def backward(self,e):
    self.fn_deriv = self.df(self.activations)
    if self.use_backwards_weights:
      if self.use_backwards_nonlinearities:
        out = torch.matmul(e * self.fn_deriv, self.backward_weights)
      else:
        out = torch.matmul(e, self.backward_weights)
    else:
      if self.use_backwards_nonlinearities:
        out = torch.matmul(e * self.fn_deriv, self.weights.T)
      else:
        out = torch.matmul(e, self.weights.T)
    return torch.clamp(out,-50,50)

  def DFA_update(self, e):
    if self.use_backwards_nonlinearities:
      self.fn_deriv = self.df(self.activations)
      dw = torch.matmul(self.inp.T, e * self.fn_deriv)
    else:
      dw = torch.matmul(self.inp.T, e)
    self.weights -= self.learning_rate * torch.clamp(dw*2,-50,50)
    return dw

  def update_weights(self,e,update_weights=False,DFA=False):
    if DFA is True:
      return self.DFA_update(e)
    else:
      self.fn_deriv = self.df(self.activations)
      if self.use_backwards_weights:
        if self.use_backwards_nonlinearities:
          delta = torch.matmul((e * self.fn_deriv).T,self.inp)
          dw = torch.matmul(self.inp.T, e * self.fn_deriv)
        else:
          delta = torch.matmul(e.T, self.inp)
          dw = torch.matmul(self.inp.T, e)
        if update_weights:
          self.weights -= self.learning_rate * torch.clamp(dw*2,-50,50)
          if self.update_backwards_weights:
            self.backward_weights -= self.learning_rate * torch.clamp(delta*2,-50,50)
      else:
        if self.use_backwards_nonlinearities:
          dw = torch.matmul(self.inp.T, e * self.fn_deriv)
        else:
          dw = torch.matmul(self.inp.T, e)
        if update_weights:
          self.weights -= self.learning_rate * torch.clamp(dw*2,-50,50)
      return dw

  def get_true_weight_grad(self):
    return self.weights.grad

  def set_weight_parameters(self):
    self.weights = nn.Parameter(self.weights)

# %% [markdown]
# # PCNet

# %%
class PCNet(object):
  def __init__(self, layers, n_inference_steps_train, inference_learning_rate, weight_learning_rate,use_error_weights=False,device='cpu'):
    self.layers= layers
    self.n_inference_steps_train = n_inference_steps_train
    self.inference_learning_rate = inference_learning_rate
    self.weight_learning_rate = weight_learning_rate
    self.device = device
    self.L = len(self.layers)
    self.outs = [[] for i in  range(self.L+1)]
    self.prediction_errors = [[] for i in range(self.L+1)]
    self.predictions = [[] for i in range(self.L+1)]
    self.mus = [[] for i in range(self.L+1)]
    self.use_error_weights = use_error_weights
    self.error_weights = []
    for i,l in enumerate(self.layers):
      if self.use_error_weights:
        #error_weight = set_tensor(torch.empty([l.input_size, l.input_size]).normal_(mean=0.0, std=0.05))
        #if i == 0:
        #  error_weight = set_tensor(torch.eye(l.input_size))
        #else:
          error_weight = (0.0 * set_tensor(torch.eye(l.input_size))) + set_tensor(torch.empty([l.input_size, l.input_size]).normal_(mean=0.0, std=0.05))
      else:
        error_weight = set_tensor(torch.eye(l.input_size))
      self.error_weights.append(error_weight)
    for l in self.layers:
      l.set_weight_parameters()

  def update_weights(self,print_weight_grads=True,get_errors=False):
    weight_diffs = []
    for (i,l) in enumerate(self.layers):
      dW = l.update_weights(self.prediction_errors[i+1],update_weights=True)
      #true_dW = l.update_weights(self.predictions[i+1],update_weights=True)
      #if print_weight_grads:
      #  diff = torch.sum((dW -true_dW)**2)
      #  weight_diffs.append(diff)
    return weight_diffs

  def update_error_weights(self):
    for (i,l) in enumerate(self.layers):
      if i != 0:
        #error_connection_delta = torch.matmul(self.outs[i].T,self.prediction_errors[i]) 
        error_connection_delta = torch.matmul(self.mus[i].T, self.prediction_errors[i]) #WORKING
        #print(error_connection_delta.shape)
        #error_connection_delta = torch.matmul(self.v_pred_errs[i+1],self.v_layers[i].mu.T)
        #self.error_weights[i] -=  self.weight_learning_rate * torch.clamp(error_connection_delta,-1,1) 
        self.error_weights[i] -=  self.weight_learning_rate * torch.clamp(error_connection_delta,-50,50)
        #print(self.error_weights[i])
        print(self.error_weights[i])
        #pass

  def forward(self,x):
    for i,l in enumerate(self.layers):
      x = l.forward(x)
    return x

  def no_grad_forward(self,x):
    with torch.no_grad():
      for i,l in enumerate(self.layers):
        x = l.forward(x)
      return x

  def infer(self, inp,label,n_inference_steps=None):
    self.n_inference_steps_train = n_inference_steps if n_inference_steps is not None else self.n_inference_steps_train
    with torch.no_grad():
      self.mus[0] = inp.clone()
      self.outs[0] = inp.clone()
      for i,l in enumerate(self.layers):
        self.mus[i+1] = l.forward(self.mus[i])
        self.outs[i+1] = self.mus[i+1].clone()
      self.mus[-1] = label.clone()
      self.prediction_errors[-1] = self.mus[-1] - self.outs[-1] 
      self.predictions[-1] = self.prediction_errors[-1].clone()
      for n in range(self.n_inference_steps_train):
        for j in reversed(range(len(self.layers))):
          #if j != 0: 
          self.prediction_errors[j] = self.mus[j] - torch.matmul(self.outs[j],self.error_weights[j])
          self.prediction_errors[j] = torch.matmul(self.mus[j],self.error_weights[j]) -self.outs[j]
          self.predictions[j] = self.layers[j].backward(self.prediction_errors[j+1])
          dx_l = self.prediction_errors[j] - self.predictions[j]
          #print(dx_l.shape)
          self.mus[j] -= self.inference_learning_rate * (2*dx_l)
        #if self.use_error_weights: 
        #  self.update_error_weights()

      weight_diffs = self.update_weights()
      if self.use_error_weights:
        self.update_error_weights()
      L = torch.sum(self.prediction_errors[-1]**2).item()
      acc = accuracy(self.no_grad_forward(inp),label)
      return L,acc,weight_diffs

  def train(self,dataset,n_epochs,n_inference_steps):
    for epoch in range(n_epochs):
      print("Epoch: ", epoch)
      for i,(inp, label) in enumerate(dataset):
        L, acc,weight_diffs = self.infer(inp.to(DEVICE),onehot(label).to(DEVICE))
        print("Epoch: " + str(epoch) + " batch: " + str(i))
        print("Loss: ", L)
        print("Acc: ", acc)
        #print("weight diffs: ", weight_diffs)

# %% [markdown]
# # Backprop Net

# %%
class BackpropNet(object):
  def __init__(self, layers,numerical_check=False,device="cpu"):
    self.layers = layers 
    self.device = device
    self.xs = [[] for i in range(len(self.layers)+1)]
    self.e_ys = [[] for i in range(len(self.layers)+1)]
    if numerical_check:
      for l in self.layers:
        l.set_weight_parameters()

  def forward(self, inp):
    self.xs[0] = inp
    for i,l in enumerate(self.layers):
      self.xs[i+1] = l.forward(self.xs[i])
    return self.xs[-1]

  def backward(self,e_y):
    self.e_ys[-1] = e_y
    for (i,l) in reversed(list(enumerate(self.layers))):
      self.e_ys[i] = l.backward(self.e_ys[i+1])
    return self.e_ys[0]

  def update_weights(self,print_weight_grads=False,update_weight=False):
    for (i,l) in enumerate(self.layers):
      dW = l.update_weights(self.e_ys[i+1],update_weights=update_weight)
      if print_weight_grads:
        print("weight grads : ", i)
        print("dW: ", dW*2)
        print("weight grad: ",l.get_true_weight_grad())

  def train(self, dataset,n_epochs):
    #train on a single datapoint here just to test to see if it works
    with torch.no_grad():
      for n in range(n_epochs):
        print("Epoch: ",n)
        for (inp,label) in dataset:
          out = self.forward(inp.to(DEVICE))
          label = onehot(label).to(DEVICE)
          e_y = out - label
          self.backward(e_y)
          #print("out: ",out[0,:])
          #print("label: ",label[0,:])
          self.update_weights(update_weight=True)
          print("Loss: ", torch.sum(e_y**2))
          print("Accuracy: ", accuracy(out,label))



def pytorch_tutorial_net_numerical_check():
  print("beginning numerical check")
  lr = 0.001
  inp = nn.Parameter(images.to(DEVICE))
  l1 = FCLayer(784,300,64,lr,tanh,tanh_deriv,use_backwards_weights= False, use_backwards_nonlinearities=True,device=DEVICE)
  l2 = FCLayer(300,100,64,lr,tanh,tanh_deriv,use_backwards_weights= False, use_backwards_nonlinearities=True,device=DEVICE)
  l3 = FCLayer(100,10,64,lr,tanh,linear_deriv,use_backwards_weights= False, use_backwards_nonlinearities=True,device=DEVICE)
  layers =[l1,l2,l3]
  net = BackpropNet(layers,numerical_check=True,device=DEVICE)
  out = net.forward(inp)
  print(out.shape)
  true_out = onehot(labels).to(DEVICE)
  print(true_out.shape)
  L = torch.sum((out - true_out)**2)
  L.backward()
  e_y = out.detach() - true_out
  dX = net.backward(e_y)
  print("true inp grad: ", inp.grad)
  print("net grad: ", dX*2)
  dw = net.update_weights(print_weight_grads =True)



#pytorch_tutorial_net_numerical_check()

# %% [markdown]
# # DFA network

# %%
class DFANet(object):
  def __init__(self, layers,numerical_check=False,device="cpu"):
    self.layers = layers 
    self.device = device
    self.xs = [[] for i in range(len(self.layers)+1)]
    self.e_ys = [[] for i in range(len(self.layers)+1)]
    self.DFA_backwards_weights = [torch.empty([10,l.output_size]).normal_(mean=0, std=1).to(self.device) for l in self.layers]
    self.DFA_backwards_weights[-1] = torch.eye(10,10).to(self.device)
    if numerical_check:
      for l in self.layers:
        l.set_weight_parameters()

  def forward(self, inp):
    self.xs[0] = inp
    for i,l in enumerate(self.layers):
      self.xs[i+1] = l.forward(self.xs[i])
    return self.xs[-1]

  def backward(self,e_y):
    self.e_ys[-1] = e_y
    return self.e_ys[-1]

  def update_weights(self,print_weight_grads=False,update_weight=False,shallow=False):
    for (i,l) in enumerate(self.layers):
      if shallow:
        if i <= len(self.layers)-1:
          update_weight=False
        else:
          update_weight=update_weight
      dW = l.update_weights(torch.matmul(self.e_ys[-1],self.DFA_backwards_weights[i]),update_weights=update_weight,DFA=True)
      if print_weight_grads:
        print("weight grads : ", i)
        print("dW: ", dW*2)
        print("weight grad: ",l.get_true_weight_grad())

  def train(self, dataset,n_epochs):
    #train on a single datapoint here just to test to see if it works
    with torch.no_grad():
      for n in range(n_epochs):
        print("Epoch: ",n)
        for (inp,label) in dataset:
          out = self.forward(inp.to(DEVICE))
          label = onehot(label).to(DEVICE)
          e_y = out - label
          self.backward(e_y)
          #print("out: ",out[0,:])
          #print("label: ",label[0,:])
          self.update_weights(update_weight=True)
          print("Loss: ", torch.sum(e_y**2))
          print("Accuracy: ", accuracy(out,label))



def pytorch_tutorial_net_numerical_check():
  print("beginning numerical check")
  lr = 0.001
  inp = nn.Parameter(images.to(DEVICE))
  l1 = FCLayer(784,300,64,lr,tanh,tanh_deriv,use_backwards_weights= False, use_backwards_nonlinearities=True,device=DEVICE)
  l2 = FCLayer(300,100,64,lr,tanh,tanh_deriv,use_backwards_weights= False, use_backwards_nonlinearities=True,device=DEVICE)
  l3 = FCLayer(100,10,64,lr,tanh,linear_deriv,use_backwards_weights= False, use_backwards_nonlinearities=True,device=DEVICE)
  layers =[l1,l2,l3]
  net = BackpropNet(layers,numerical_check=True,device=DEVICE)
  out = net.forward(inp)
  print(out.shape)
  true_out = onehot(labels).to(DEVICE)
  print(true_out.shape)
  L = torch.sum((out - true_out)**2)
  L.backward()
  e_y = out.detach() - true_out
  dX = net.backward(e_y)
  print("true inp grad: ", inp.grad)
  print("net grad: ", dX*2)
  dw = net.update_weights(print_weight_grads =True)

# %% [markdown]
# # Training

# %%
# right so FA is just update_backwards_weights = False and use_backwards_weights True
lr = 0.0005
n_inference_steps_train = 100
inference_learning_rate =0.02
weight_learning_rate = 0.005
use_backwards_weights= False
use_backwards_nonlinearities=True
use_error_weights=True
update_backwards_weights = True
n_epochs = 10000
l1 = FCLayer(784,300,64,lr,tanh,tanh_deriv,use_backwards_weights= use_backwards_weights, update_backwards_weights = update_backwards_weights, use_backwards_nonlinearities=use_backwards_nonlinearities,device=DEVICE)
l2 = FCLayer(300,100,64,lr,tanh,tanh_deriv,use_backwards_weights= use_backwards_weights, update_backwards_weights = update_backwards_weights,use_backwards_nonlinearities=use_backwards_nonlinearities,device=DEVICE)
l3 = FCLayer(100,10,64,lr,tanh,linear_deriv,use_backwards_weights= use_backwards_weights,update_backwards_weights = update_backwards_weights, use_backwards_nonlinearities=use_backwards_nonlinearities,device=DEVICE)
layers =[l1,l2,l3]
#net = PCNet(layers,n_inference_steps_train,inference_learning_rate,weight_learning_rate,use_error_weights=use_error_weights,device=DEVICE)
#net = BackpropNet(layers)
net = DFANet(layers,device=DEVICE)
#net.train([dataset[0]],n_epochs)
net.train(dataset[0:-2],n_epochs)
# Out:
# Streaming output truncated to the last 5000 lines.
# Accuracy:  0.84375
# Loss:  tensor(24.9885, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(34.1909, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(25.5060, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.5756, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.3504, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.3493, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.6445, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(29.7140, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.3011, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.1274, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.1144, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(34.3427, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.9062, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.5329, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.9314, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.9502, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.6533, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.7061, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.4087, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.7509, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.2005, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(26.1035, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.8794, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.6616, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(32.3177, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.3151, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.8345, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.0700, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(33.6597, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.5202, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.0228, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.0756, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(32.5755, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(24.3903, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.7656, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(27.7825, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.4354, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(26.5292, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.3421, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.2766, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(34.8001, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(27.2849, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.0041, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.8261, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(29.4673, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.5080, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(27.0168, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(25.2995, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.2449, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(33.0454, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.8242, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.8875, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.5497, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.0604, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(27.8301, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.6121, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.1015, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(28.9913, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.5417, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(29.3171, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.1803, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.6826, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(30.2091, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(26.7176, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(26.9794, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(25.4134, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.8593, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.8279, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.7643, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.6089, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.5833, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.5638, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(36.5559, device='cuda:0')
# Accuracy:  0.671875
# Loss:  tensor(30.4533, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(30.3234, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.4964, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.0561, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.5369, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(22.6226, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(28.4848, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.9176, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(30.7704, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.3336, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.4515, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.3956, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.5891, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.4394, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.8641, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.5128, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(36.1429, device='cuda:0')
# Accuracy:  0.6875
# Loss:  tensor(32.5946, device='cuda:0')
# Accuracy:  0.71875
# Loss:  tensor(32.0624, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.8612, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.1844, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.6706, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.2666, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.4726, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.7920, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.9245, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.5682, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.5200, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.7510, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.4394, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.7113, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.6917, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.3118, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.3023, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.6122, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(26.6055, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.8394, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.1718, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.0417, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.7949, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(24.6946, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(31.1101, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.6930, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.3934, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.0257, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(33.9329, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(32.4796, device='cuda:0')
# Accuracy:  0.71875
# Loss:  tensor(30.2036, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.2070, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(32.6844, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(30.1603, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.5507, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.9978, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(30.6787, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.3939, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.8999, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.4266, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.4975, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.9265, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.1881, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(30.6891, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(30.3388, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.6854, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.3073, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.3659, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(35.7845, device='cuda:0')
# Accuracy:  0.703125
# Loss:  tensor(27.2519, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(29.8779, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.8545, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.9043, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(23.9331, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(33.4044, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.7673, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.0246, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.1371, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(30.4312, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.7674, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.8876, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.1068, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.2440, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.7577, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.0626, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.8788, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.7221, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.5519, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.5319, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(30.6819, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.0421, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.4163, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.8332, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.9169, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.1972, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.6766, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.3958, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.6321, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.1788, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.0612, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(33.3306, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(29.3588, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.5602, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.4010, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.3945, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.7928, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.4682, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4000, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(32.1002, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.5033, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(25.2619, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.7824, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.8379, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(32.0551, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(26.2017, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(33.1322, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.1433, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.6620, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(35.6457, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(30.6660, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.1572, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.1060, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(22.0831, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(25.5617, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.2509, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.2770, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.0513, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(32.0923, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.9967, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(21.4740, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(30.0721, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.7906, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.6856, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.2550, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.6590, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.6132, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.7993, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(32.5262, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.9707, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(25.1966, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.8371, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.9591, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(24.8114, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.9238, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.2670, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.9818, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.4493, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.0263, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4776, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.7903, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(32.1052, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.6993, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(30.5034, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(34.7145, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(28.7736, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.1767, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(26.0141, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.3792, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.4641, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.0614, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.6203, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.8271, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.5837, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.7494, device='cuda:0')
# Accuracy:  0.78125
# Epoch:  52
# Loss:  tensor(31.2126, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.0680, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.9952, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.8826, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(26.0379, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.1192, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.8270, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.1401, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.3000, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.4048, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.7948, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.1037, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(25.8692, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.8445, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.0141, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.3484, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(33.7859, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(28.3346, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.2217, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.1415, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.2059, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(26.6216, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.8341, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.8618, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.9758, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.2169, device='cuda:0')
# Accuracy:  0.71875
# Loss:  tensor(29.6508, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.9257, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(30.3703, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.9384, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.2793, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(33.3672, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(31.9491, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.6383, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.2949, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.0029, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.5277, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.6670, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.3279, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(29.7763, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.7032, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(24.2420, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(31.0248, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.4579, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(27.0758, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.1198, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.9929, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.3848, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.2011, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.6246, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.4135, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.6377, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.1041, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.8927, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.5579, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.6844, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.7012, device='cuda:0')
# Accuracy:  0.71875
# Loss:  tensor(25.5375, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.9737, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.2296, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(27.4603, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.3266, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.6773, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.8171, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.1247, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.0635, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(30.4612, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.9708, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.1788, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.5859, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.4034, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.7167, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(22.4916, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(30.3853, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(24.3846, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.1602, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.5965, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.7501, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.6222, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(26.3614, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(23.3709, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.2701, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.6619, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.7210, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.9170, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.8574, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.9117, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.6131, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.9916, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.2743, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.0653, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.0956, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.3840, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(33.2293, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.6705, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.4316, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.5324, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.0782, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.2684, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.2866, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.0971, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(24.1125, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(27.5138, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.6175, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(27.5833, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.1188, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.0506, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.7124, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.1856, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.3902, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.7654, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.7746, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.8314, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.0740, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.8338, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.8183, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.5058, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.1333, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.2495, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.7254, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.3619, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.4693, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.0453, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.7939, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.9726, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(29.6817, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.2185, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.5490, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.8370, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.7366, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.3678, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.9722, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.8812, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.1091, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.0076, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.2800, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.6456, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(30.0662, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.8872, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.9056, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(31.7026, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.5821, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.8715, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.9223, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.9110, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.7355, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.6328, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.0514, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.0596, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.6106, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.7683, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.5050, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.2865, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4851, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(21.7494, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.5523, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.2011, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.2596, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.9835, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.3227, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.9131, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.3690, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.2959, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.3616, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.0891, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.6460, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.4460, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.1181, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.1119, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.8114, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.4215, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.2087, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(24.4939, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.7509, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(26.6668, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.1064, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.7771, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.8080, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.7884, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.6633, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.8484, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(34.5207, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(25.8219, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.3260, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.9569, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.7187, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.1897, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(32.1005, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.3359, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.4793, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.2591, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(32.9010, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(22.7306, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.6965, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.6726, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.8117, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(25.0272, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.2445, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.4011, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.9019, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(34.2907, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(31.2221, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.1885, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.6165, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.1014, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.5377, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(27.7591, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.9737, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.7206, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.9168, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.8832, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.1023, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.2388, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(33.9757, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(34.1975, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(26.1565, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(28.8700, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(26.7743, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.3760, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.0811, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(32.6581, device='cuda:0')
# Accuracy:  0.6875
# Loss:  tensor(28.0001, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.8905, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.4200, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.7795, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(26.8038, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.4630, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.8770, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.3361, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.0766, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.7926, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.8682, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(33.2610, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.5494, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.7125, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(24.7519, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.8535, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(25.6417, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.2988, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.8973, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.5769, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.5297, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.5434, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.9382, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(26.4302, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.6554, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4142, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.7763, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.1631, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.2255, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(33.2566, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.5595, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.4312, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.2774, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.0864, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.5930, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.5810, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.3903, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(24.6302, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(26.2375, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4053, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.8481, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.0671, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(32.7627, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.4642, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.2247, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.9414, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.7396, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.3573, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.8070, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.7144, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.7796, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.0756, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.8616, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.8102, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.9497, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.3721, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.6552, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(25.7105, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.1935, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.0210, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.2830, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.1711, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(31.0856, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(26.6293, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(36.2666, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(30.4986, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.1356, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.5868, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.3147, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(34.1650, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(36.6419, device='cuda:0')
# Accuracy:  0.6875
# Loss:  tensor(28.4323, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.1528, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.6687, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.9357, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.4100, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.9074, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.1380, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.3686, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.7449, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.4428, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.5116, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.2210, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.7155, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.6337, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.4975, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.1652, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.8233, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.3636, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.8992, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(34.5573, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.6494, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(34.9011, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.1355, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.7352, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.7807, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.9835, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.1188, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.1247, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.6521, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.0533, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.6898, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.7466, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(32.6642, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.5187, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.6644, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.2105, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.9864, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.2695, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.2389, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.3773, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(33.9291, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.2152, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.5073, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.5925, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(33.7013, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.4769, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.0664, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.6589, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.5228, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.4896, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.0516, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.1076, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.2519, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.1165, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.8250, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.3542, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.5953, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.9555, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.2930, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.4044, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(26.3165, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.9976, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.6680, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(28.1516, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.9153, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(24.5810, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.8367, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.1190, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.5904, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(23.7829, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.3418, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.0011, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.8038, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.0239, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(32.5953, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(28.2797, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.7429, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.4409, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(36.7453, device='cuda:0')
# Accuracy:  0.71875
# Loss:  tensor(29.7008, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.5679, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.7337, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.7773, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(34.1995, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.5990, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.9930, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.9728, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.0370, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.2933, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.9102, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.4152, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.6965, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.6339, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.6470, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.9441, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.1382, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(24.2236, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.8134, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.8992, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.2324, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(26.7557, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.8732, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.6008, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.4481, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.3127, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(24.9316, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.4485, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.6089, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.8929, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.8730, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.8616, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.9744, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(32.7753, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.6167, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.9904, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.6922, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.0828, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.0379, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.6343, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.6028, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.5019, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.2500, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.0117, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(32.2852, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.6586, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(25.8620, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.4207, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.8533, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.7967, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(29.7573, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.1772, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.1213, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(24.3226, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.9142, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.6254, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.9506, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.5749, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.0362, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(31.0648, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.5836, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.3882, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.8871, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.2157, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.5580, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.6524, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(22.7770, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(25.6507, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.1678, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(29.2267, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.5063, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.7099, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.6061, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.3463, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.1060, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.5810, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(31.3999, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.3266, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.3843, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.1082, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(26.6018, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.9286, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.5056, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(33.7875, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(29.3691, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.5100, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.5936, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.7812, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(35.2776, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(34.1768, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(27.8996, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.3618, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.6846, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.0674, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.3470, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.5484, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.9855, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.3560, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(31.4074, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.3433, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(29.9889, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.5727, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.2635, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.4602, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.8387, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.3253, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.8673, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.0339, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.1659, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.5517, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(29.0596, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.8892, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.8169, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.6584, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.0127, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.1216, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.1456, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.4325, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.2483, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(30.6198, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.3179, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.7916, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(32.4964, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.7714, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.2932, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.7161, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.3325, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.0985, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(25.7400, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(32.4392, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.8275, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.0715, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.9340, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.7211, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.9114, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.2560, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.9789, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.7190, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.0773, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.2911, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.3688, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.3145, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.8892, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.3451, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.6494, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.3373, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.8101, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.9413, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(30.4963, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.8936, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.4430, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.9634, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.4706, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(26.2010, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.2371, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.2421, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.1786, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.7611, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.2762, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.0513, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.0584, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(29.1743, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(33.7383, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(27.3653, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.2072, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.7519, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(24.3683, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(27.4122, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.5616, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(29.7054, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.5956, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.6339, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.8030, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(30.5929, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.6925, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.9383, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.2502, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(29.2226, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(30.9454, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.1026, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.4513, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.2435, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.1553, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.8552, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.5187, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.3730, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(29.0738, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(27.5904, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.8667, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(27.5429, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.7232, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.7545, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.8596, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.8313, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.7003, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.3971, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(28.9179, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.5743, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.7797, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(33.6467, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(29.0066, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.5837, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.9956, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(35.3643, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(31.6547, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.7588, device='cuda:0')
# ...
# Accuracy:  0.9375
# Loss:  tensor(31.6235, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.5460, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.8258, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.8647, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.8128, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.6845, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.5881, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.9994, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.0468, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.5815, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.7450, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.4402, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.2753, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4164, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(21.6935, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.5017, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.1802, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.2097, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.9260, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(27.2804, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.8672, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.3237, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.2534, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.3377, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.0644, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.5990, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.4272, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.0931, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.0891, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.7690, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.3633, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.1496, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(24.4486, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(25.7230, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(26.6105, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.0732, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.7448, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.7608, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.7387, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.6290, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.8106, device='cuda:0')
# Accuracy:  0.9375
# Loss:  tensor(34.4936, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(25.8034, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(25.2580, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.9397, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.7137, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.1303, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(32.0444, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.2466, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.4458, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.2065, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(32.8510, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(22.7110, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.6465, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.6340, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.7520, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(25.0101, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.2141, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.3312, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.8503, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(34.2153, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(31.1894, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.1430, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(31.6190, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.0861, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.4875, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(27.6941, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.9109, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.7069, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.8721, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.8449, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.0593, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.1566, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(33.9534, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(34.1797, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(26.1398, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(28.8357, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(26.7121, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.3215, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.0360, device='cuda:0')
# Accuracy:  0.75
# Loss:  tensor(32.6267, device='cuda:0')
# Accuracy:  0.6875
# Loss:  tensor(27.9060, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.8789, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.3658, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(32.7393, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(26.7473, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.4154, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.8144, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(27.2851, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.0226, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.7883, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.8477, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(33.2394, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.4998, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(28.6980, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(24.7068, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(29.8097, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(25.5877, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.3001, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.8373, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.5345, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.4945, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.4961, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.8972, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(26.3949, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.6014, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.3643, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.7741, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.0599, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.1741, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(33.2231, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.5605, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.4011, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(25.2186, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.0658, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(27.5560, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.5288, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.3512, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(24.5658, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(26.1970, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.3554, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.7839, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(32.0353, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(32.7600, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.4080, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.1356, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.9125, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.6910, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.3321, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.7736, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.6728, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.7339, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.0381, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(32.8067, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.7699, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.8760, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.3041, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(28.6193, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(25.6419, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.1716, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.0125, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.2053, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.0959, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(31.0721, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(26.5950, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(36.2116, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(30.4704, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.0967, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.5933, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.2400, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(34.0973, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(36.6372, device='cuda:0')
# Accuracy:  0.6875
# Loss:  tensor(28.3569, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(27.0773, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(27.6131, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.9015, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.3769, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.8884, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.0892, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(32.2890, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.7090, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(28.3916, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(28.4483, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.1572, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.6891, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.5634, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(31.4412, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.1306, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.8181, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(33.3411, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.8445, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(34.5304, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(28.5697, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(34.8412, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(29.0918, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.7031, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.7299, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.9547, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.0660, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.1063, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(26.6110, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(24.9831, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.6405, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.7092, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(32.6323, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(31.4770, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.6417, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.1590, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(25.9698, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(30.2345, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.1650, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(30.3569, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(33.8565, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(31.1972, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.4479, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(30.5578, device='cuda:0')
# Accuracy:  0.78125
# Loss:  tensor(33.7048, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.4390, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(30.0123, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.5834, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.4629, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.4285, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(27.0115, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.0820, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(32.2212, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.0233, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(31.7883, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(34.3174, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(27.5247, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(29.9302, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(30.2804, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(29.3787, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.2730, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(30.9297, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(25.6059, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(28.1057, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(28.9030, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.5547, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.7824, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(29.0611, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.5392, device='cuda:0')
# Accuracy:  0.921875
# Loss:  tensor(23.7299, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(26.2990, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(27.9921, device='cuda:0')
# Accuracy:  0.8125
# Loss:  tensor(29.7798, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(31.9654, device='cuda:0')
# Accuracy:  0.765625
# Loss:  tensor(32.5750, device='cuda:0')
# Accuracy:  0.734375
# Loss:  tensor(28.2243, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.6652, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.3991, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(36.7134, device='cuda:0')
# Accuracy:  0.71875
# Loss:  tensor(29.6731, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(31.5189, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(27.6693, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(29.6927, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(34.1672, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(26.5777, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(26.9307, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(28.8964, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.9799, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(28.2340, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.8648, device='cuda:0')
# Accuracy:  0.859375
# Loss:  tensor(24.3811, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(30.6371, device='cuda:0')
# Accuracy:  0.796875
# Loss:  tensor(28.6146, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(25.6282, device='cuda:0')
# Accuracy:  0.90625
# Loss:  tensor(27.9332, device='cuda:0')
# Accuracy:  0.828125
# Loss:  tensor(29.0675, device='cuda:0')
# Accuracy:  0.84375
# Loss:  tensor(24.1526, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(28.7667, device='cuda:0')
# Accuracy:  0.890625
# Loss:  tensor(29.8557, device='cuda:0')
# Accuracy:  0.875
# Loss:  tensor(26.1490, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-71-2113e16b5238> in <module>()
#      17 net = DFANet(layers,device=DEVICE)
#      18 #net.train([dataset[0]],n_epochs)
# ---> 19 net.train(dataset[0:-2],n_epochs)
#
# <ipython-input-69-d3b3a975441b> in train(self, dataset, n_epochs)
#      48           self.update_weights(update_weight=True)
#      49           print("Loss: ", torch.sum(e_y**2))
# ---> 50           print("Accuracy: ", accuracy(out,label))
#      51
#      52
#
# <ipython-input-5-64b43bb7fa5a> in accuracy(out, L)
#      44   total = 0
#      45   for i in range(B):
# ---> 46     if torch.argmax(out[i,:]) == torch.argmax(L[i,:]):
#      47       total +=1
#      48   return total/ B
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in wrapped(*args, **kwargs)
#      26     def wrapped(*args, **kwargs):
#      27         try:
# ---> 28             return f(*args, **kwargs)
#      29         except TypeError:
#      30             return NotImplemented
#
# KeyboardInterrupt:
